# %%
import pandas as pd
import log_df

# %%
df = log_df.get_dataframe(False)

# %%
for i in df['date_time']:
    x = i.split('/')

# %%
df['date_time'][1][3:6]
# Out:
# 'Apr'

# %%
df
# Out:
#                       date_time http_status method  protocol  \
# 0     16/Apr/2019:19:34:42+0000         200    GET  HTTP/1.1
# 1     16/Apr/2019:19:34:44+0000         200    GET  HTTP/1.1
# 2     16/Apr/2019:19:34:46+0000         200    GET  HTTP/1.1
# 3     16/Apr/2019:19:34:48+0000         200    GET  HTTP/1.1
# 4     16/Apr/2019:19:34:50+0000         200    GET  HTTP/1.1
# 5     16/Apr/2019:19:34:52+0000         200    GET  HTTP/1.1
# 6     16/Apr/2019:19:34:53+0000         200    GET  HTTP/1.1
# 7     16/Apr/2019:19:34:54+0000         200    GET  HTTP/1.1
# 8     16/Apr/2019:19:34:56+0000         200    GET  HTTP/1.1
# 9     16/Apr/2019:19:34:58+0000         200    GET  HTTP/1.1
# 10    16/Apr/2019:19:35:01+0000         200    GET  HTTP/1.1
# 11    16/Apr/2019:19:35:03+0000         200    GET  HTTP/1.1
# 12    16/Apr/2019:19:35:05+0000         200    GET  HTTP/1.1
# 13    16/Apr/2019:19:35:07+0000         200    GET  HTTP/1.1
# ...
