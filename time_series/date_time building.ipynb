# %%
import pandas as pd
import acquire

# %%
df = acquire.acquire_sales()

# %%
list(df.columns)
# Out:
# ['item_id',
#  'sale_amount',
#  'sale_date',
#  'sale_id',
#  'store_id',
#  'item_brand',
#  'item_name',
#  'item_price',
#  'item_upc12',
#  'item_upc14',
#  'store_address',
#  'store_city',
#  'store_state',
#  'store_zipcode']

# %%
df['sale_date'] = pd.to_datetime(df['sale_date'],utc=True)

# %%
# Out:
#         item_id  sale_amount                 sale_date  sale_id  store_id  \
# 0             1         13.0 2013-01-01 00:00:00+00:00        1         1
# 1             1         11.0 2013-01-02 00:00:00+00:00        2         1
# 2             1         14.0 2013-01-03 00:00:00+00:00        3         1
# 3             1         13.0 2013-01-04 00:00:00+00:00        4         1
# 4             1         10.0 2013-01-05 00:00:00+00:00        5         1
# 5             1         12.0 2013-01-06 00:00:00+00:00        6         1
# 6             1         10.0 2013-01-07 00:00:00+00:00        7         1
# 7             1          9.0 2013-01-08 00:00:00+00:00        8         1
# 8             1         12.0 2013-01-09 00:00:00+00:00        9         1
# 9             1          9.0 2013-01-10 00:00:00+00:00       10         1
# 10            1          9.0 2013-01-11 00:00:00+00:00       11         1
# 11            1          7.0 2013-01-12 00:00:00+00:00       12         1
# ...
